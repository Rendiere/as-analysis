# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

sns.set()

# %%
import sys
sys.path.append('../')

import data_utils as util

# %% [markdown]
# ## Load Demographics  and BASMI data

# %%
demo_df = pd.read_excel('../data/demographics and Biologics data.xlsx', index_col=0)

# Get year of birth for estimating age
year_of_birth = pd.DataFrame(demo_df['year of Birth'])

# Subselect and rename some columns
demo_df = demo_df[['patient_gender_id','patient_date_of_diagnosis']]
demo_df.rename(columns={'patient_gender_id': 'gender', 'patient_date_of_diagnosis': 'diagnosis_date'}, inplace=True)

basmi_df = pd.read_excel('../data/clean_basmi.xls', index_col=(0,1)).reset_index(level=1, drop=False)
basmi_df.head()
# Out:
#                  Date  CRS  TWS  LSFS  LFS  IMS   BS Drug
# patient_id
# 40         1995-05-09    3    1     6    5    3  3.6  NaN
# 40         1995-06-01    3    1     8    5    3  4.0  NaN
# 40         1995-06-12    2    1     5    3    2  2.6  NaN
# 40         1995-11-02    1    1     3    4    2  2.2  NaN
# 40         1996-05-02    2    1     4    3    2  2.4  NaN

# %% [markdown]
# ## Data Pre-processing & Setup

# %%
# Add year of birth to BASMI data
df = pd.merge(basmi_df, year_of_birth, left_index=True, right_index=True)

# Convert Drug to binary
df['Drug'] = df['Drug'].notnull()

# Add patient age using year of birth
df['Age'] = df['Date'].dt.year - df['year of Birth']
df.drop('year of Birth', axis=1, inplace=True)

# Bin age into 10 bins
bins = [np.floor(x) for x in np.linspace(df['Age'].values.min(), df['Age'].values.max(), 11)]
labels = range(1,11)
df['Age_cat'] = pd.cut(df['Age'], bins=bins, labels=labels)

df.head()
# Out:
#                  Date  CRS  TWS  LSFS  LFS  IMS   BS   Drug  Age Age_cat
# patient_id
# 40         1995-05-09    3    1     6    5    3  3.6  False   48       5
# 40         1995-06-01    3    1     8    5    3  4.0  False   48       5
# 40         1995-06-12    2    1     5    3    2  2.6  False   48       5
# 40         1995-11-02    1    1     3    4    2  2.2  False   48       5
# 40         1996-05-02    2    1     4    3    2  2.4  False   49       5

# %% [markdown]
# ### Normalize patient timeline

# %%
def get_norm_years(dates):
    """
    Different from get_norm_years in data_utils
    
    ->  Calculates normlized timeline using start year as 0 
        and increments for each subsequent year
    
    ->  Originally increments for every year included in study
    
    For example, if patient joined in May 1995, next year increment would
    have been June 1996. Now it will increment on Jan 1996. 
    """
    
    years = [d.year for d in dates]
    start_year = min(years)
    norm_years = [year - start_year for year in years]
    
    return norm_years


df['norm_years'] = df.groupby(['patient_id'])['Date'].transform(get_norm_years)

df.head()
# Out:
#                  Date  CRS  TWS  LSFS  LFS  IMS   BS   Drug  Age Age_cat  \
# patient_id
# 40         1995-05-09    3    1     6    5    3  3.6  False   48       5
# 40         1995-06-01    3    1     8    5    3  4.0  False   48       5
# 40         1995-06-12    2    1     5    3    2  2.6  False   48       5
# 40         1995-11-02    1    1     3    4    2  2.2  False   48       5
# 40         1996-05-02    2    1     4    3    2  2.4  False   49       5
#
#             norm_years
# patient_id
# 40                   0
# 40                   0
# 40                   0
# 40                   0
# 40                   1

# %% [markdown]
# ### Aggregate by year in study
#
# For each patient, calculate aggregated scores for every year in the study
#
# * TODO - generalize this to be able to aggregate for other periods

# %%
def agg_by_norm_year(df, agg_dict={}):
    return df.groupby(['patient_id','norm_years']).agg(agg_dict)

# Aggregate the data for each patient by normalized year
# Keep the actual year of each norm_year
agg_dict={'BS': 'mean', 'Age': min, 'Drug': np.any, 'Date': lambda x: x.iloc[0].year}
agg_df = agg_by_norm_year(df,agg_dict).rename(columns={'Date': 'year'})

# Add Gender and Diagnosis Date to aggregated, normalized data
agg_df = demo_df.join(agg_df).reset_index().set_index('patient_id')


# Add time since diagnosis variable
agg_df['time_since_diagnosis'] = agg_df['year'] - agg_df['diagnosis_date'].dt.year
agg_df.drop('diagnosis_date', axis=1, inplace=True)
agg_df.head()
# Out:
#             norm_years  gender   BS  Age   Drug  year  time_since_diagnosis
# patient_id
# 40                   0  Female  3.1   48  False  1995                   1.0
# 40                   1  Female  2.4   49  False  1996                   2.0
# 40                   2  Female  3.0   50  False  1997                   3.0
# 40                   3  Female  3.4   51  False  1998                   4.0
# 40                   4  Female  3.3   52  False  1999                   5.0

# %% [markdown]
# # Implement LMM

# %% [markdown]
# Start with using `Drug` and `norm_years` as the predictors and using `BS` as the outcome.
#
# Thus, we have:
#
# \begin{equation}
# \mathbf{y} = \mathbf{X}\mathbf{\beta} + \mathbf{Z}\mathbf{u} + \mathbf{\epsilon}
# \end{equation}

# %%
ids_list = agg_df.index 
patient_ids = ids_list.unique()

n_patients = len(patient_ids)
n_samples = agg_df.shape[0]

ids_to_idx = {p_id:idx for idx,p_id in enumerate(patient_ids)}
samples_idx = list(range(n_samples))

y = agg_df['BS'].values

X = agg_df[['norm_years', 'Drug']]
X['Drug'] = X["Drug"].astype(int)



# Z = np.zeros(shape=(n_samples, n_patients))

# # populate the Z array with 1's for each sample in the column
# # corresponding to patient 
# for idx, row in enumerate(Z):
#     # patient ID that this sample belongs to
#     p_id = ids_list[idx]
    
#     # The column index of this ID
#     p_id_idx = ids_to_idx[p_id]
    
#     row[p_id_idx] = 1
    
# Z.shape
# Out:
# /Users/renierbotha/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# (8472, 688)

# %%
X_fe = X['Drug']
X_re = X['norm_years']

# %%
from statsmodels.regression.mixed_linear_model import MixedLM
lm = MixedLM(endog=y, exog=X_fe.values, groups=ids_list, exog_re = X_re.values)

result = lm.fit()

result

# %%
result.bse
# Out:
# array([ 0.14978339,  0.00317433])

# %%
result.random_effects
# Out:
# {40: x_re1    0.298459
#  dtype: float64, 41: x_re1    1.093174
#  dtype: float64, 43: x_re1    0.115722
#  dtype: float64, 44: x_re1    0.46347
#  dtype: float64, 45: x_re1    0.350435
#  dtype: float64, 46: x_re1    0.195203
#  dtype: float64, 47: x_re1    0.431782
#  dtype: float64, 50: x_re1    0.026166
#  dtype: float64, 51: x_re1    0.303885
#  dtype: float64, 52: x_re1    0.152704
#  dtype: float64, 53: x_re1    0.533961
#  dtype: float64, 54: x_re1    0.586661
#  dtype: float64, 55: x_re1    0.537485
#  dtype: float64, 57: x_re1    0.188981
#  dtype: float64, 59: x_re1    0.532256
#  dtype: float64, 60: x_re1    0.463901
#  dtype: float64, 61: x_re1    0.421323
#  dtype: float64, 63: x_re1    0.297384
#  dtype: float64, 65: x_re1    0.112247
#  dtype: float64, 67: x_re1    0.207302
#  dtype: float64, 68: x_re1    0.097625
#  dtype: float64, 69: x_re1    0.22988
#  dtype: float64, 70: x_re1    0.387373
#  dtype: float64, 71: x_re1    0.339904
#  dtype: float64, 72: x_re1    0.251682
#  dtype: float64, 73: x_re1    0.089757
#  dtype: float64, 75: x_re1    0.650449
#  dtype: float64, 76: x_re1    0.140681
#  dtype: float64, 78: x_re1    0.138295
#  dtype: float64, 79: x_re1    0.297336
#  dtype: float64, 80: x_re1    0.301733
#  dtype: float64, 81: x_re1    0.185104
#  dtype: float64, 82: x_re1    0.31021
#  dtype: float64, 83: x_re1    0.521524
#  dtype: float64, 84: x_re1    0.92017
#  dtype: float64, 85: x_re1    0.271246
#  dtype: float64, 86: x_re1    0.83354
#  dtype: float64, 87: x_re1    0.238071
#  dtype: float64, 88: x_re1    0.409914
#  dtype: float64, 89: x_re1    0.206612
#  dtype: float64, 90: x_re1    0.401339
#  dtype: float64, 92: x_re1    0.060647
#  dtype: float64, 93: x_re1    0.295281
#  dtype: float64, 95: x_re1    0.079541
#  dtype: float64, 96: x_re1    0.223451
#  dtype: float64, 98: x_re1    0.51073
#  dtype: float64, 99: x_re1    0.279656
#  dtype: float64, 100: x_re1    0.988862
#  dtype: float64, 102: x_re1    0.045995
#  dtype: float64, 103: x_re1    0.0539
#  dtype: float64, 104: x_re1    0.431198
#  dtype: float64, 105: x_re1    0.365666
#  dtype: float64, 108: x_re1    0.292942
#  dtype: float64, 110: x_re1    0.444684
#  dtype: float64, 111: x_re1    0.322669
#  dtype: float64, 112: x_re1    0.438904
#  dtype: float64, 114: x_re1    0.447565
#  dtype: float64, 115: x_re1    0.507466
#  dtype: float64, 118: x_re1    0.550597
#  dtype: float64, 119: x_re1    0.146321
#  dtype: float64, 120: x_re1    0.302999
#  dtype: float64, 121: x_re1    0.207776
#  dtype: float64, 122: x_re1    0.177926
#  dtype: float64, 124: x_re1    0.434944
#  dtype: float64, 125: x_re1    0.145601
#  dtype: float64, 127: x_re1    0.197669
#  dtype: float64, 128: x_re1    0.219496
#  dtype: float64, 129: x_re1    0.193401
#  dtype: float64, 130: x_re1    0.286142
#  dtype: float64, 131: x_re1    0.654527
#  dtype: float64, 132: x_re1    0.30235
#  dtype: float64, 134: x_re1    0.272597
#  dtype: float64, 135: x_re1    0.3548
#  dtype: float64, 136: x_re1    0.227159
#  dtype: float64, 138: x_re1    0.137535
#  dtype: float64, 139: x_re1    0.376011
#  dtype: float64, 140: x_re1    0.271747
#  dtype: float64, 141: x_re1    0.266004
#  dtype: float64, 142: x_re1    0.544329
#  dtype: float64, 143: x_re1    0.108645
#  dtype: float64, 144: x_re1    0.12094
#  dtype: float64, 145: x_re1    0.099634
#  dtype: float64, 147: x_re1    0.890014
#  dtype: float64, 148: x_re1    0.083964
#  dtype: float64, 149: x_re1    0.313364
#  dtype: float64, 150: x_re1    0.291518
#  dtype: float64, 151: x_re1    0.168341
#  dtype: float64, 152: x_re1    0.318689
#  dtype: float64, 154: x_re1    0.391885
#  dtype: float64, 155: x_re1    0.237548
#  dtype: float64, 156: x_re1    0.212097
#  dtype: float64, 157: x_re1    0.476956
#  dtype: float64, 162: x_re1    0.222351
#  dtype: float64, 163: x_re1    0.242212
#  dtype: float64, 165: x_re1    0.43031
#  dtype: float64, 171: x_re1    0.312143
#  dtype: float64, 173: x_re1    0.608208
#  dtype: float64, 174: x_re1    0.175102
#  dtype: float64, 175: x_re1    0.07313
#  dtype: float64, 176: x_re1    0.473304
#  dtype: float64, 177: x_re1    0.681125
#  dtype: float64, 178: x_re1    0.223423
#  dtype: float64, 179: x_re1    0.252296
#  dtype: float64, 181: x_re1    0.294138
#  dtype: float64, 184: x_re1    0.251934
#  dtype: float64, 185: x_re1    0.598093
#  dtype: float64, 186: x_re1    0.424393
#  dtype: float64, 187: x_re1    0.274085
#  dtype: float64, 188: x_re1    0.592601
#  dtype: float64, 191: x_re1    0.662927
#  dtype: float64, 192: x_re1    0.755143
#  dtype: float64, 193: x_re1    0.273837
#  dtype: float64, 194: x_re1    0.232438
#  dtype: float64, 195: x_re1    0.171202
#  dtype: float64, 196: x_re1    0.282927
#  dtype: float64, 197: x_re1    0.175282
#  dtype: float64, 199: x_re1    0.291926
#  dtype: float64, 200: x_re1    0.323904
#  dtype: float64, 206: x_re1    0.245283
#  dtype: float64, 208: x_re1    0.723737
#  dtype: float64, 210: x_re1    0.097173
#  dtype: float64, 211: x_re1    0.212016
#  dtype: float64, 212: x_re1    0.347306
#  dtype: float64, 218: x_re1    0.436869
#  dtype: float64, 219: x_re1    0.26806
#  dtype: float64, 221: x_re1    0.107264
#  dtype: float64, 222: x_re1    1.03324
#  dtype: float64, 223: x_re1    0.435308
#  dtype: float64, 224: x_re1    1.018381
#  dtype: float64, 225: x_re1    0.207173
#  dtype: float64, 226: x_re1    0.073796
#  dtype: float64, 227: x_re1    0.261029
#  dtype: float64, 231: x_re1    0.279266
#  dtype: float64, 233: x_re1    0.697161
#  dtype: float64, 235: x_re1    0.569264
#  dtype: float64, 236: x_re1    0.879348
#  dtype: float64, 237: x_re1    0.364499
#  dtype: float64, 238: x_re1    0.634472
#  dtype: float64, 239: x_re1    0.071911
#  dtype: float64, 240: x_re1    0.538155
#  dtype: float64, 242: x_re1    0.107157
#  dtype: float64, 243: x_re1    0.266877
#  dtype: float64, 244: x_re1    0.454489
#  dtype: float64, 245: x_re1    0.498634
#  dtype: float64, 246: x_re1    0.126916
#  dtype: float64, 247: x_re1    0.078408
#  dtype: float64, 249: x_re1    0.204899
#  dtype: float64, 254: x_re1    0.467957
#  dtype: float64, 256: x_re1    0.645769
#  dtype: float64, 257: x_re1    0.404357
#  dtype: float64, 261: x_re1    0.417387
#  dtype: float64, 262: x_re1    1.097499
#  dtype: float64, 264: x_re1    0.412086
#  dtype: float64, 266: x_re1    0.680274
#  dtype: float64, 269: x_re1    0.250722
#  dtype: float64, 270: x_re1    0.695877
#  dtype: float64, 271: x_re1    0.960536
#  dtype: float64, 272: x_re1    0.328516
#  dtype: float64, 273: x_re1    0.291892
#  dtype: float64, 274: x_re1    0.179629
#  dtype: float64, 275: x_re1    0.662935
#  dtype: float64, 276: x_re1    0.558816
#  dtype: float64, 277: x_re1    0.104075
#  dtype: float64, 278: x_re1    0.340701
#  dtype: float64, 279: x_re1    0.289728
#  dtype: float64, 282: x_re1    0.174051
#  dtype: float64, 284: x_re1    0.398115
#  dtype: float64, 286: x_re1    0.06919
#  dtype: float64, 287: x_re1    0.210264
#  dtype: float64, 288: x_re1    1.446177
#  dtype: float64, 289: x_re1    0.394449
#  dtype: float64, 296: x_re1    0.292863
#  dtype: float64, 297: x_re1    0.670459
#  dtype: float64, 299: x_re1    0.290609
#  dtype: float64, 300: x_re1    0.380735
#  dtype: float64, 301: x_re1    0.321332
#  dtype: float64, 303: x_re1    0.025072
#  dtype: float64, 304: x_re1    0.061742
#  dtype: float64, 305: x_re1    0.156834
#  dtype: float64, 306: x_re1    0.253698
#  dtype: float64, 308: x_re1    0.567714
#  dtype: float64, 309: x_re1    0.255932
#  dtype: float64, 311: x_re1    0.04757
#  dtype: float64, 313: x_re1    0.121149
#  dtype: float64, 315: x_re1    0.077554
#  dtype: float64, 319: x_re1    0.746937
#  dtype: float64, 320: x_re1    0.3117
#  dtype: float64, 321: x_re1    0.611056
#  dtype: float64, 322: x_re1    0.176625
#  dtype: float64, 324: x_re1    0.406672
#  dtype: float64, 325: x_re1    0.590173
#  dtype: float64, 326: x_re1    0.952034
#  dtype: float64, 327: x_re1    0.221088
#  dtype: float64, 328: x_re1    0.204864
#  dtype: float64, 329: x_re1    0.351901
#  dtype: float64, 330: x_re1    0.524863
#  dtype: float64, 336: x_re1    0.106468
#  dtype: float64, 339: x_re1    0.145977
#  dtype: float64, 342: x_re1    0.622908
#  dtype: float64, 343: x_re1    0.457061
#  dtype: float64, 345: x_re1    0.345523
#  dtype: float64, 347: x_re1    0.22334
#  dtype: float64, 348: x_re1    0.139911
#  dtype: float64, 353: x_re1    0.217035
#  dtype: float64, 357: x_re1    0.012836
#  dtype: float64, 358: x_re1    0.517266
#  dtype: float64, 359: x_re1    0.350381
#  dtype: float64, 360: x_re1    0.235721
#  dtype: float64, 361: x_re1    0.034508
#  dtype: float64, 362: x_re1    0.318374
#  dtype: float64, 363: x_re1    0.238312
#  dtype: float64, 366: x_re1    0.371972
#  dtype: float64, 368: x_re1    0.242726
#  dtype: float64, 371: x_re1    0.64604
#  dtype: float64, 373: x_re1    0.803185
#  dtype: float64, 374: x_re1    0.954794
#  dtype: float64, 379: x_re1    0.304872
#  dtype: float64, 381: x_re1    0.348618
#  dtype: float64, 382: x_re1    0.733751
#  dtype: float64, 383: x_re1    0.083487
#  dtype: float64, 384: x_re1    0.199296
#  dtype: float64, 385: x_re1    0.427135
#  dtype: float64, 386: x_re1    0.346667
#  dtype: float64, 387: x_re1    0.155025
#  dtype: float64, 390: x_re1    0.383109
#  dtype: float64, 392: x_re1    0.594803
#  dtype: float64, 393: x_re1    0.59599
#  dtype: float64, 394: x_re1    0.52651
#  dtype: float64, 395: x_re1    0.31822
#  dtype: float64, 396: x_re1    0.214163
#  dtype: float64, 398: x_re1    0.044953
#  dtype: float64, 399: x_re1    0.429622
#  dtype: float64, 401: x_re1    0.721145
#  dtype: float64, 402: x_re1    0.087895
#  dtype: float64, 403: x_re1    0.325858
#  dtype: float64, 404: x_re1    0.39687
#  dtype: float64, 405: x_re1    0.883219
#  dtype: float64, 406: x_re1    0.186173
#  dtype: float64, 408: x_re1    0.466354
#  dtype: float64, 410: x_re1    1.064646
#  dtype: float64, 411: x_re1    0.065063
#  dtype: float64, 412: x_re1    0.204944
#  dtype: float64, 414: x_re1    0.249996
#  dtype: float64, 415: x_re1    0.477697
#  dtype: float64, 416: x_re1    0.543324
#  dtype: float64, 417: x_re1    0.461712
#  dtype: float64, 418: x_re1    0.115963
#  dtype: float64, 419: x_re1    0.308424
#  dtype: float64, 421: x_re1    0.21929
#  dtype: float64, 422: x_re1    0.306533
#  dtype: float64, 423: x_re1    0.663371
#  dtype: float64, 424: x_re1    0.433721
#  dtype: float64, 426: x_re1    0.137549
#  dtype: float64, 430: x_re1    0.377401
#  dtype: float64, 433: x_re1    0.294758
#  dtype: float64, 434: x_re1    0.198598
#  dtype: float64, 435: x_re1    0.131474
#  dtype: float64, 436: x_re1    0.789378
#  dtype: float64, 437: x_re1    0.414256
#  dtype: float64, 438: x_re1    0.420388
#  dtype: float64, 439: x_re1    0.357948
#  dtype: float64, 440: x_re1    0.37068
#  dtype: float64, 443: x_re1    0.300346
#  dtype: float64, 446: x_re1    0.373043
#  dtype: float64, 447: x_re1    0.481839
#  dtype: float64, 451: x_re1    0.71815
#  dtype: float64, 452: x_re1    0.335623
#  dtype: float64, 453: x_re1    0.89584
#  dtype: float64, 454: x_re1    0.069117
#  dtype: float64, 455: x_re1    0.292882
#  dtype: float64, 457: x_re1    0.159373
#  dtype: float64, 461: x_re1    0.363046
#  dtype: float64, 462: x_re1    0.529835
#  dtype: float64, 464: x_re1    0.367069
#  dtype: float64, 466: x_re1    0.500443
#  dtype: float64, 467: x_re1    0.393249
#  dtype: float64, 469: x_re1    0.078129
#  dtype: float64, 470: x_re1    0.254725
#  dtype: float64, 471: x_re1    0.318908
#  dtype: float64, 472: x_re1    0.182428
#  dtype: float64, 473: x_re1    0.76653
#  dtype: float64, 478: x_re1    0.334937
#  dtype: float64, 479: x_re1    0.34672
#  dtype: float64, 483: x_re1    0.321925
#  dtype: float64, 484: x_re1    0.204462
#  dtype: float64, 486: x_re1    0.086974
#  dtype: float64, 490: x_re1    0.348641
#  dtype: float64, 491: x_re1    0.36246
#  dtype: float64, 492: x_re1    0.368042
#  dtype: float64, 493: x_re1    0.126645
#  dtype: float64, 498: x_re1    0.159798
#  dtype: float64, 501: x_re1    0.352608
#  dtype: float64, 507: x_re1    0.200829
#  dtype: float64, 508: x_re1    0.601841
#  dtype: float64, 510: x_re1    0.390342
#  dtype: float64, 511: x_re1    0.304908
#  dtype: float64, 513: x_re1    0.84868
#  dtype: float64, 515: x_re1    0.062727
#  dtype: float64, 517: x_re1    0.346145
#  dtype: float64, 518: x_re1    0.28338
#  dtype: float64, 520: x_re1    0.329824
#  dtype: float64, 524: x_re1    0.709926
#  dtype: float64, 527: x_re1    0.027423
#  dtype: float64, 530: x_re1    0.230082
#  dtype: float64, 532: x_re1    0.281124
#  dtype: float64, 534: x_re1    0.100042
#  dtype: float64, 535: x_re1    0.239687
#  dtype: float64, 540: x_re1    0.176894
#  dtype: float64, 541: x_re1    0.250606
#  dtype: float64, 543: x_re1    0.082007
#  dtype: float64, 547: x_re1    0.056317
#  dtype: float64, 548: x_re1    0.188139
#  dtype: float64, 552: x_re1    0.563564
#  dtype: float64, 554: x_re1    0.248707
#  dtype: float64, 563: x_re1    0.69632
#  dtype: float64, 566: x_re1    0.111726
#  dtype: float64, 568: x_re1    0.247734
#  dtype: float64, 571: x_re1    0.433307
#  dtype: float64, 574: x_re1    0.717017
#  dtype: float64, 576: x_re1    0.139383
#  dtype: float64, 577: x_re1    0.068126
#  dtype: float64, 578: x_re1    0.914247
#  dtype: float64, 579: x_re1    0.027694
#  dtype: float64, 581: x_re1    0.057523
#  dtype: float64, 582: x_re1    0.210963
#  dtype: float64, 583: x_re1    0.542262
#  dtype: float64, 586: x_re1    0.207511
#  dtype: float64, 590: x_re1    0.366679
#  dtype: float64, 594: x_re1    0.351865
#  dtype: float64, 595: x_re1    0.309663
#  dtype: float64, 596: x_re1    0.34216
#  dtype: float64, 598: x_re1    0.090085
#  dtype: float64, 599: x_re1    0.231407
#  dtype: float64, 601: x_re1    0.182212
#  dtype: float64, 606: x_re1    0.307498
#  dtype: float64, 611: x_re1    0.376279
#  dtype: float64, 615: x_re1    0.32729
#  dtype: float64, 620: x_re1    0.274252
#  dtype: float64, 621: x_re1    0.377366
#  dtype: float64, 622: x_re1    0.255011
#  dtype: float64, 624: x_re1    0.161497
#  dtype: float64, 626: x_re1    0.060552
#  dtype: float64, 627: x_re1    0.570008
#  dtype: float64, 629: x_re1    0.049166
#  dtype: float64, 631: x_re1    0.482545
#  dtype: float64, 632: x_re1    0.539322
#  dtype: float64, 640: x_re1    0.110183
#  dtype: float64, 641: x_re1    0.148719
#  dtype: float64, 643: x_re1    0.429078
#  dtype: float64, 646: x_re1    0.867395
#  dtype: float64, 647: x_re1    0.396129
#  dtype: float64, 650: x_re1    0.070125
#  dtype: float64, 651: x_re1    0.111331
#  dtype: float64, 655: x_re1    0.301454
#  dtype: float64, 656: x_re1    0.14206
#  dtype: float64, 657: x_re1    0.743839
#  dtype: float64, 659: x_re1    0.534486
#  dtype: float64, 662: x_re1    0.086233
#  dtype: float64, 663: x_re1    0.32589
#  dtype: float64, 666: x_re1    0.116479
#  dtype: float64, 667: x_re1    0.056088
#  dtype: float64, 668: x_re1    0.049659
#  dtype: float64, 669: x_re1    0.044967
#  dtype: float64, 673: x_re1    0.419566
#  dtype: float64, 678: x_re1    0.159267
#  dtype: float64, 681: x_re1    0.285271
#  dtype: float64, 682: x_re1    0.21506
#  dtype: float64, 683: x_re1    0.272721
#  dtype: float64, 684: x_re1    0.027631
#  dtype: float64, 685: x_re1    0.43398
#  dtype: float64, 686: x_re1    0.104763
#  dtype: float64, 687: x_re1    0.048929
#  dtype: float64, 688: x_re1    0.252713
#  dtype: float64, 694: x_re1    0.391546
#  dtype: float64, 696: x_re1    0.36656
#  dtype: float64, 698: x_re1    1.116363
#  dtype: float64, 699: x_re1    0.745252
#  dtype: float64, 700: x_re1    0.69527
#  dtype: float64, 704: x_re1    0.431136
#  dtype: float64, 705: x_re1    0.410575
#  dtype: float64, 707: x_re1    0.06338
#  dtype: float64, 709: x_re1    0.182592
#  dtype: float64, 710: x_re1    0.165111
#  dtype: float64, 711: x_re1    0.241841
#  dtype: float64, 719: x_re1    0.275002
#  dtype: float64, 722: x_re1    0.403679
#  dtype: float64, 724: x_re1    0.822578
#  dtype: float64, 731: x_re1    0.165165
#  dtype: float64, 732: x_re1    0.298308
#  dtype: float64, 733: x_re1    0.082576
#  dtype: float64, 737: x_re1    0.244848
#  dtype: float64, 740: x_re1    0.431587
#  dtype: float64, 741: x_re1    0.084306
#  dtype: float64, 742: x_re1    0.282029
#  dtype: float64, 743: x_re1    0.564544
#  dtype: float64, 744: x_re1    0.923932
#  dtype: float64, 751: x_re1    0.08639
#  dtype: float64, 753: x_re1    0.603108
#  dtype: float64, 754: x_re1    0.744141
#  dtype: float64, 756: x_re1    0.290069
#  dtype: float64, 758: x_re1    0.492461
#  dtype: float64, 759: x_re1    0.254412
#  dtype: float64, 761: x_re1    0.148041
#  dtype: float64, 762: x_re1    0.226715
#  dtype: float64, 765: x_re1    0.443034
#  dtype: float64, 772: x_re1    0.163465
#  dtype: float64, 775: x_re1    0.146121
#  dtype: float64, 777: x_re1    0.367633
#  dtype: float64, 785: x_re1    0.364185
#  dtype: float64, 786: x_re1    0.645025
#  dtype: float64, 790: x_re1    0.387327
#  dtype: float64, 791: x_re1    0.674514
#  dtype: float64, 792: x_re1    0.277982
#  dtype: float64, 795: x_re1    0.210681
#  dtype: float64, 798: x_re1    0.17534
#  dtype: float64, 805: x_re1    0.145789
#  dtype: float64, 808: x_re1    0.306412
#  dtype: float64, 809: x_re1    0.402272
#  dtype: float64, 829: x_re1    0.422439
#  dtype: float64, 833: x_re1    0.172781
#  dtype: float64, 837: x_re1    0.065485
#  dtype: float64, 844: x_re1    0.253344
#  dtype: float64, 847: x_re1    0.24009
#  dtype: float64, 850: x_re1    0.289897
#  dtype: float64, 851: x_re1    0.478035
#  dtype: float64, 855: x_re1    0.390896
#  dtype: float64, 1417: x_re1    0.586914
#  dtype: float64, 1454: x_re1    0.146371
#  dtype: float64, 1562: x_re1    0.310309
#  dtype: float64, 1716: x_re1    0.450847
#  dtype: float64, 1749: x_re1    0.501969
#  dtype: float64, 1829: x_re1    0.29999
#  dtype: float64, 1863: x_re1    0.400909
#  dtype: float64, 1872: x_re1    0.236908
#  dtype: float64, 1935: x_re1    0.260647
#  dtype: float64, 2007: x_re1    0.846078
#  dtype: float64, 2023: x_re1    0.163144
#  dtype: float64, 2061: x_re1    0.174361
#  dtype: float64, 2158: x_re1    0.243556
#  dtype: float64, 2168: x_re1    0.395062
#  dtype: float64, 2278: x_re1    0.302386
#  dtype: float64, 2364: x_re1    0.331072
#  dtype: float64, 2365: x_re1    0.486958
#  dtype: float64, 2377: x_re1    0.169789
#  dtype: float64, 2448: x_re1    0.648814
#  dtype: float64, 2466: x_re1    0.269999
#  dtype: float64, 2486: x_re1    0.30763
#  dtype: float64, 2489: x_re1    0.314611
#  dtype: float64, 2498: x_re1    0.759641
#  dtype: float64, 2563: x_re1    0.551492
#  dtype: float64, 2569: x_re1    0.213645
#  dtype: float64, 2574: x_re1    0.237456
#  dtype: float64, 2600: x_re1    0.564654
#  dtype: float64, 2612: x_re1    0.269806
#  dtype: float64, 2713: x_re1    0.986481
#  dtype: float64, 2729: x_re1    0.253299
#  dtype: float64, 2742: x_re1    0.184746
#  dtype: float64, 2794: x_re1    0.0
#  dtype: float64, 2825: x_re1    0.179674
#  dtype: float64, 2844: x_re1    0.440376
#  dtype: float64, 2851: x_re1    1.218575
#  dtype: float64, 2858: x_re1    0.463856
#  dtype: float64, 2864: x_re1    0.786592
#  dtype: float64, 2941: x_re1    0.191443
#  dtype: float64, 2957: x_re1    0.0
#  dtype: float64, 3027: x_re1    0.051275
#  dtype: float64, 3050: x_re1    0.43479
#  dtype: float64, 3058: x_re1    0.230625
#  dtype: float64, 3081: x_re1    1.027527
#  dtype: float64, 3101: x_re1    0.11601
#  dtype: float64, 3151: x_re1    0.51911
#  dtype: float64, 3169: x_re1    0.248636
#  dtype: float64, 3179: x_re1    0.446251
#  dtype: float64, 3180: x_re1    0.418266
#  dtype: float64, 3193: x_re1    0.389959
#  dtype: float64, 3223: x_re1    0.079165
#  dtype: float64, 3265: x_re1    0.875137
#  dtype: float64, 3273: x_re1    0.152696
#  dtype: float64, 3282: x_re1    0.675273
#  dtype: float64, 3350: x_re1    0.479476
#  dtype: float64, 3352: x_re1    0.425287
#  dtype: float64, 3355: x_re1    0.287604
#  dtype: float64, 3380: x_re1    0.275472
#  dtype: float64, 3502: x_re1    0.455144
#  dtype: float64, 3504: x_re1    0.497388
#  dtype: float64, 3520: x_re1    0.0
#  dtype: float64, 3558: x_re1    0.282012
#  dtype: float64, 3577: x_re1    0.37288
#  dtype: float64, 3625: x_re1    1.307574
#  dtype: float64, 3723: x_re1    0.107891
#  dtype: float64, 3730: x_re1    0.35094
#  dtype: float64, 3736: x_re1    0.477832
#  dtype: float64, 3751: x_re1    0.214155
#  dtype: float64, 3766: x_re1    0.26204
#  dtype: float64, 3767: x_re1    0.369384
#  dtype: float64, 3812: x_re1    0.120039
#  dtype: float64, 3813: x_re1    0.246374
#  dtype: float64, 3815: x_re1    0.377061
#  dtype: float64, 3824: x_re1    0.38535
#  dtype: float64, 3830: x_re1    0.139526
#  dtype: float64, 3872: x_re1    0.847249
#  dtype: float64, 3892: x_re1    0.321989
#  dtype: float64, 3936: x_re1    0.153383
#  dtype: float64, 3981: x_re1    0.758639
#  dtype: float64, 4068: x_re1    0.196554
#  dtype: float64, 4104: x_re1    0.640079
#  dtype: float64, 4117: x_re1    0.492077
#  dtype: float64, 4165: x_re1    0.406362
#  dtype: float64, 4278: x_re1    0.084981
#  dtype: float64, 4318: x_re1    0.415848
#  dtype: float64, 4364: x_re1    0.35456
#  dtype: float64, 4407: x_re1    0.043096
#  dtype: float64, 4413: x_re1    0.092446
#  dtype: float64, 4472: x_re1    0.23529
#  dtype: float64, 4478: x_re1    0.105664
#  dtype: float64, 4557: x_re1    0.11593
#  dtype: float64, 4562: x_re1    0.129217
#  dtype: float64, 4568: x_re1    0.049991
#  dtype: float64, 4601: x_re1    0.404187
#  dtype: float64, 4618: x_re1    0.178094
#  dtype: float64, 4651: x_re1    0.053624
#  dtype: float64, 4661: x_re1    0.4056
#  dtype: float64, 4662: x_re1    0.0
#  dtype: float64, 4673: x_re1    0.308306
#  dtype: float64, 4679: x_re1    0.852692
#  dtype: float64, 4686: x_re1    0.203589
#  dtype: float64, 4746: x_re1    0.183314
#  dtype: float64, 4846: x_re1    0.483419
#  dtype: float64, 4876: x_re1    1.126272
#  dtype: float64, 4933: x_re1    0.623196
#  dtype: float64, 4970: x_re1    0.058469
#  dtype: float64, 4981: x_re1    0.08831
#  dtype: float64, 5037: x_re1    0.094004
#  dtype: float64, 5090: x_re1    0.365951
#  dtype: float64, 5095: x_re1    0.0
#  dtype: float64, 5112: x_re1    0.256387
#  dtype: float64, 5125: x_re1    0.160489
#  dtype: float64, 5145: x_re1    0.0
#  dtype: float64, 5154: x_re1    0.045449
#  dtype: float64, 5189: x_re1    0.197468
#  dtype: float64, 5297: x_re1    0.054391
#  dtype: float64, 5422: x_re1    0.019407
#  dtype: float64, 5792: x_re1    0.0
#  dtype: float64, 6022: x_re1    0.288861
#  dtype: float64, 6207: x_re1    0.467094
#  dtype: float64, 6299: x_re1    0.077353
#  dtype: float64, 6308: x_re1    0.054917
#  dtype: float64, 6310: x_re1    0.419905
#  dtype: float64, 6313: x_re1    0.137226
#  dtype: float64, 6318: x_re1    0.532636
#  dtype: float64, 6552: x_re1    0.195111
#  dtype: float64, 6635: x_re1    0.217945
#  dtype: float64, 6637: x_re1    0.229531
#  dtype: float64, 6639: x_re1    0.099698
#  dtype: float64, 6643: x_re1    0.151007
#  dtype: float64, 6646: x_re1    0.064898
#  dtype: float64, 6671: x_re1    0.579981
#  dtype: float64, 6691: x_re1    0.412322
#  dtype: float64, 6737: x_re1    1.022416
#  dtype: float64, 7227: x_re1    0.374458
#  dtype: float64, 7229: x_re1    0.71966
#  dtype: float64, 7230: x_re1    0.833249
#  dtype: float64, 7234: x_re1    0.420874
#  dtype: float64, 7247: x_re1    0.083315
#  dtype: float64, 7248: x_re1    0.368613
#  dtype: float64, 7254: x_re1    0.541182
#  dtype: float64, 7260: x_re1    0.025544
#  dtype: float64, 7265: x_re1    0.042729
#  dtype: float64, 7274: x_re1    0.386374
#  dtype: float64, 7283: x_re1    0.418886
#  dtype: float64, 7290: x_re1    0.106794
#  dtype: float64, 7304: x_re1    0.62381
#  dtype: float64, 7307: x_re1    0.51674
#  dtype: float64, 7311: x_re1    0.0
#  dtype: float64, 7313: x_re1    0.377729
#  dtype: float64, 7319: x_re1    0.10255
#  dtype: float64, 7320: x_re1    0.0
#  dtype: float64, 7330: x_re1    0.494461
#  dtype: float64, 7336: x_re1    0.593353
#  dtype: float64, 7338: x_re1    0.472706
#  dtype: float64, 7343: x_re1    0.0
#  dtype: float64, 7345: x_re1    0.0
#  dtype: float64, 7374: x_re1    0.369917
#  dtype: float64, 7383: x_re1    0.392525
#  dtype: float64, 7387: x_re1    0.178981
#  dtype: float64, 7389: x_re1    0.171333
#  dtype: float64, 7390: x_re1    0.033996
#  dtype: float64, 7392: x_re1    0.128187
#  dtype: float64, 7396: x_re1    0.594819
#  dtype: float64, 7398: x_re1    1.419124
#  dtype: float64, 7401: x_re1    0.645154
#  dtype: float64, 7419: x_re1    0.324147
#  dtype: float64, 7420: x_re1    0.13246
#  dtype: float64, 7423: x_re1    0.272802
#  dtype: float64, 7429: x_re1    0.151371
#  dtype: float64, 7433: x_re1    0.841523
#  dtype: float64, 7445: x_re1    0.703233
#  dtype: float64, 7448: x_re1    1.019343
#  dtype: float64, 7454: x_re1    0.079761
#  dtype: float64, 7460: x_re1    0.267643
#  dtype: float64, 7462: x_re1    0.259573
#  dtype: float64, 7466: x_re1    0.251496
#  dtype: float64, 7471: x_re1    0.416648
#  dtype: float64, 7472: x_re1    0.174719
#  dtype: float64, 7482: x_re1    0.364577
#  dtype: float64, 7485: x_re1    0.714141
#  dtype: float64, 7486: x_re1    0.577415
#  dtype: float64, 7488: x_re1    0.02991
#  dtype: float64, 7493: x_re1    0.163916
#  dtype: float64, 7497: x_re1    0.123914
#  dtype: float64, 7501: x_re1    0.133799
#  dtype: float64, 7503: x_re1    0.051275
#  dtype: float64, 7506: x_re1    0.235928
#  dtype: float64, 7511: x_re1    0.362886
#  dtype: float64, 7514: x_re1    0.284542
#  dtype: float64, 7530: x_re1    0.576227
#  dtype: float64, 7531: x_re1    0.060599
#  dtype: float64, 7533: x_re1    0.11601
#  dtype: float64, 7540: x_re1    0.852299
#  dtype: float64, 7548: x_re1    0.686751
#  dtype: float64, 7555: x_re1    0.095517
#  dtype: float64, 7557: x_re1    0.144081
#  dtype: float64, 7559: x_re1    0.228317
#  dtype: float64, 7565: x_re1    0.451122
#  dtype: float64, 7573: x_re1    0.231608
#  dtype: float64, 7583: x_re1    0.65331
#  dtype: float64, 7591: x_re1    0.230018
#  dtype: float64, 7593: x_re1    0.666636
#  dtype: float64, 7596: x_re1    1.099006
#  dtype: float64, 7598: x_re1    0.877398
#  dtype: float64, 7599: x_re1    0.120221
#  dtype: float64, 7620: x_re1    0.655324
#  dtype: float64, 7627: x_re1    0.094929
#  dtype: float64, 7653: x_re1    1.049828
#  dtype: float64, 7656: x_re1    0.135525
#  dtype: float64, 7661: x_re1    0.410572
#  dtype: float64, 7662: x_re1    0.256202
#  dtype: float64, 7663: x_re1    0.028762
#  dtype: float64, 7667: x_re1    0.0
#  dtype: float64, 7672: x_re1    0.114638
#  dtype: float64, 7674: x_re1    0.0
#  dtype: float64, 7675: x_re1    0.340676
#  dtype: float64, 7680: x_re1    0.0
#  dtype: float64, 7686: x_re1    0.503451
#  dtype: float64, 7687: x_re1    0.0
#  dtype: float64, 7689: x_re1    0.266181
#  dtype: float64, 7697: x_re1    0.662396
#  dtype: float64, 7712: x_re1    0.216044
#  dtype: float64, 7713: x_re1    0.238838
#  dtype: float64, 7714: x_re1    0.008546
#  dtype: float64, 7715: x_re1    0.0
#  dtype: float64, 7726: x_re1    1.457303
#  dtype: float64, 7728: x_re1    0.559724
#  dtype: float64, 7731: x_re1    0.5303
#  dtype: float64, 7732: x_re1    0.426198
#  dtype: float64, 7739: x_re1    0.367331
#  dtype: float64, 7740: x_re1    0.303092
#  dtype: float64, 7766: x_re1    0.109606
#  dtype: float64, 7813: x_re1    1.024745
#  dtype: float64, 7818: x_re1    0.219258
#  dtype: float64, 7823: x_re1    0.0
#  dtype: float64, 7840: x_re1    0.095517
#  dtype: float64, 7847: x_re1    0.275116
#  dtype: float64, 7869: x_re1    0.0
#  dtype: float64, 7874: x_re1    0.309896
#  dtype: float64, 7903: x_re1    0.295418
#  dtype: float64, 7907: x_re1    0.0
#  dtype: float64, 7909: x_re1    0.064094
#  dtype: float64, 7921: x_re1    0.0
#  dtype: float64, 7935: x_re1    0.0
#  dtype: float64, 7959: x_re1    0.569275
#  dtype: float64, 7960: x_re1    0.272693
#  dtype: float64, 7970: x_re1    0.181796
#  dtype: float64, 7980: x_re1    0.076912
#  dtype: float64, 7985: x_re1    0.0
#  dtype: float64, 7989: x_re1    0.104928
#  dtype: float64, 7992: x_re1    0.106047
#  dtype: float64, 7995: x_re1    0.025637
#  dtype: float64, 8004: x_re1    0.0
#  dtype: float64, 8016: x_re1    0.119641
#  dtype: float64, 8077: x_re1    0.232701
#  dtype: float64, 8099: x_re1    0.39389
#  dtype: float64, 8102: x_re1    0.767502
#  dtype: float64, 8194: x_re1    0.0
#  dtype: float64, 8211: x_re1    0.0
#  dtype: float64, 8213: x_re1    0.256374
#  dtype: float64, 8228: x_re1    0.0
#  dtype: float64, 8244: x_re1    0.0
#  dtype: float64}
